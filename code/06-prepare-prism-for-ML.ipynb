# %%
# this code should mostly work to calculate rolling windows
# might need a water year var to groupby

test_ds['tmin_c_roll_3d'] = test_ds.tmin.groupby("time.year").map(
    lambda x: x.rolling(time=3, min_periods=1).mean())
